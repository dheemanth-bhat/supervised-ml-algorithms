# %% [markdown]
# ### 1.3 Data Sensitivity

# %% [markdown]
# #### Impact of Outliers

# %% [markdown]
# #### Impact of Varied Scales

# %% [markdown]
# #### Need for Feature Encoding

# %% [markdown]
# #### Impact of Imbalanced Dataset
